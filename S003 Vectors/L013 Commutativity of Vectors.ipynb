# %% [markdown]
# Is the dot product commutative?
# a' * b =?= b' * a
#
# 1) Generate two 100-element random row vectors and compute the two dot products
# 2) Generate two 2-element integer row vectors and do the same

# %%
import numpy as np

# %%
a = np.random.rand(100)
b = np.random.rand(100)
print(a)
print(b)
print("")
# Out:
# [0.46220546 0.87890079 0.87974107 0.35608239 0.34927097 0.37486766
#  0.47364822 0.65469088 0.72481213 0.57877698 0.20693783 0.89450767
#  0.04520707 0.2656252  0.18251488 0.43266654 0.86156717 0.59438765
#  0.84312881 0.66703968 0.7645139  0.66702588 0.36412014 0.43861288
#  0.71978903 0.15396565 0.41848208 0.03868637 0.63342996 0.50097183
#  0.14383576 0.83476372 0.49928017 0.44586053 0.36726388 0.87506972
#  0.55545806 0.19253036 0.77621216 0.41454515 0.46387269 0.29297362
#  0.51851284 0.17392313 0.22653876 0.55739735 0.2956394  0.53217473
#  0.85095268 0.9056672  0.75396934 0.23073422 0.69969969 0.18573086
#  0.59172633 0.89644466 0.6610318  0.46093644 0.94190234 0.57744053
#  0.3551657  0.1472705  0.12217609 0.19490781 0.6979866  0.65360694
#  0.36641665 0.393157   0.53089734 0.11486974 0.09006309 0.60368927
#  0.83884235 0.25189661 0.79713695 0.96950967 0.97758254 0.21598938
#  0.41137375 0.6601433  0.47873526 0.54163441 0.70913059 0.5278885
# ...

# %%
print (np.dot(a, b))
# Out:
# 22.947566451108933

# %%
print (np.dot(b, a))
# Out:
# 22.947566451108933

# %%
c = np.random.randint(0, 10, 2)

# %%
d = np.random.randint(0, 10, 2)

# %%
print(c, d)
# Out:
# [5 3] [4 2]

# %%
print(np.dot(c, d))

print(np.dot(d, c))
# Out:
# 26
# 26
